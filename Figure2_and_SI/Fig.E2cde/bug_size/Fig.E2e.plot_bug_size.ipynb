# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, kstest, anderson
from sklearn.metrics import r2_score
import pandas as pd

# %%
# load data
bug_data = pd.read_csv('batch_analyzed_results.csv')

# %%
# remove outliers from area > k*std < -k*std
outlier_k = 2
bug_data_clean = bug_data[(np.abs(bug_data['SHAPE.area']-bug_data['SHAPE.area'].mean()) <= (outlier_k*bug_data['SHAPE.area'].std()))]
# remove outliers from length > k*std < -k*std
outlier_k = 2
bug_data_clean = bug_data_clean[(np.abs(bug_data_clean['SHAPE.length']-bug_data_clean['SHAPE.length'].mean()) <= (outlier_k*bug_data_clean['SHAPE.length'].std()))]
# remove outliers from width.mean > k*std < -k*std
outlier_k = 2
bug_data_clean = bug_data_clean[(np.abs(bug_data_clean['SHAPE.width.mean']-bug_data_clean['SHAPE.width.mean'].mean()) <= (outlier_k*bug_data_clean['SHAPE.width.mean'].std()))]
print('before - after', len(bug_data), len(bug_data_clean))
# Out:
# before - after 7664 6764

# %%
plt.figure(figsize=(6,5.5))

color = 'darkgray'
outline_color = 'dimgray'

# Histogram settings
bin_range = (0.9, 2.6)
num_bins = 7
# Extract data
data = bug_data_clean['SHAPE.length'].values
# data = bug_data_clean['SHAPE.area'].values
# data = bug_data_clean['SHAPE.width.mean'].values

# Fit a normal distribution to the data
mu, sigma = norm.fit(data)

# Generate x values for the fitted curve
x = np.linspace(bin_range[0], bin_range[1], 100)
pdf = norm.pdf(x, mu, sigma)  # Gaussian curve

# Compute R² (coefficient of determination)
hist_values, bin_edges = np.histogram(data, bins=num_bins, range=bin_range, density=True)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2  # Compute bin centers
expected_pdf = norm.pdf(bin_centers, mu, sigma)  # Expected Gaussian values at bin centers
r2 = r2_score(hist_values, expected_pdf)

# Perform Kolmogorov-Smirnov test
ks_stat, ks_pval = kstest(data, 'norm', args=(mu, sigma))

# Perform Anderson-Darling test
ad_result = anderson(data, dist='norm')

# Plot histogram
plt.hist(data, bins=num_bins, range=bin_range, edgecolor=outline_color, 
         color=color, alpha=1, density=True, linewidth=2, label="Data")

# Overlay Gaussian fit
plt.plot(x, pdf, 'k-', linewidth=3, label="Gaussian Fit\n(R² = {:.3f})".format(r2))

# Add text about mean, std, and goodness of fit
N = len(data)
text_str = (
    f"Mean = {mu:.2f} μm\n"
    f"Std = {sigma:.2f} μm\n"
    f"N = {N}\n"
)
plt.text(0.9, 1.15, text_str, fontsize=14)

# Axis labels
plt.xlabel('Swimmer Length (μm)', fontsize=16)
plt.ylabel('Probability Density', fontsize=16)

# Adjust tick label size
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=12)

# Add legend
plt.legend(frameon=False, fontsize=14, loc='upper right')

# limits
# plt.xlim(7, 13.6)
plt.ylim(0, 1.5)

# Font sizes
ax.tick_params(axis='both', which='major', labelsize=12)  # Tick label size

# Get the current content of the labels and title
xlabel = ax.get_xlabel()
ylabel = ax.get_ylabel()
title = ax.get_title()

# Set the font sizes without changing the content
ax.set_xlabel(xlabel, fontsize=16)  # X-axis label size
ax.set_ylabel(ylabel, fontsize=16)  # Y-axis label size
ax.set_title(title, fontsize=18)  # Title size

# Set legend size (if you have a legend)
legend = ax.get_legend()
if legend:
    for label in legend.get_texts():
        label.set_fontsize(14)

# Set text size for any additional annotations
for text in ax.texts:
    text.set_fontsize(14)

# Make axes thicker
for spine in ['top', 'right', 'bottom', 'left']:
    ax.spines[spine].set_linewidth(1.5)

# Reduce num of ticks
ax.locator_params(axis='y', nbins=3)
ax.locator_params(axis='x', nbins=6)

# Save figure as PNG (optional), transparent background, tight bounding box
# plt.savefig('Bug_Length_Distribution.png', format='png', dpi=900, transparent=True, bbox_inches='tight')


# # Print goodness of fit statistics
# print("Gaussian Fit Parameters:")
# print(f"Mean (μ) = {mu:.3f}, Std (σ) = {sigma:.3f}")
# print(f"R² = {r2:.3f} (Goodness of Fit)")
